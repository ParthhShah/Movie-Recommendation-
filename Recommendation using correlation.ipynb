# %%
# import necessary libraries
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# load the dataset
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv("ratings.csv")

print(movies.head())
ratings.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
data = ratings.merge(movies,on='movieId', how='left')

# %%
data
# Out:
#         userId  movieId  rating   timestamp                           title  \
# 0            1        1     4.0   964982703                Toy Story (1995)
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...

# %% [markdown]
# # Calculating the average of the rating

# %%
Average_ratings = pd.DataFrame(data.groupby('title')['rating'].mean())
Average_ratings.head(10)
# Out:
#                                            rating
# title
# '71 (2014)                               4.000000
# 'Hellboy': The Seeds of Creation (2004)  4.000000
# 'Round Midnight (1986)                   3.500000
# 'Salem's Lot (2004)                      5.000000
# 'Til There Was You (1997)                4.000000
# 'Tis the Season for Love (2015)          1.500000
# 'burbs, The (1989)                       3.176471
# 'night Mother (1986)                     3.000000
# (500) Days of Summer (2009)              3.666667
# *batteries not included (1987)           3.285714

# %% [markdown]
# # Counting The no. of ratings done by the user for each movie

# %%
Average_ratings['Total Ratings'] = pd.DataFrame(data.groupby('title')['rating'].count())
Average_ratings.head(10)
# Out:
#                                            rating  Total Ratings
# title
# '71 (2014)                               4.000000              1
# 'Hellboy': The Seeds of Creation (2004)  4.000000              1
# 'Round Midnight (1986)                   3.500000              2
# 'Salem's Lot (2004)                      5.000000              1
# 'Til There Was You (1997)                4.000000              2
# 'Tis the Season for Love (2015)          1.500000              1
# 'burbs, The (1989)                       3.176471             17
# 'night Mother (1986)                     3.000000              1
# (500) Days of Summer (2009)              3.666667             42
# *batteries not included (1987)           3.285714              7

# %% [markdown]
# # Converting this into matrix using .pivot

# %%
movie_user = data.pivot_table(index='userId',columns='title',values='rating')

# %%
movie_user
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
# ...            ...                                      ...
# 606            NaN                                      NaN
# 607            NaN                                      NaN
# 608            NaN                                      NaN
# 609            NaN                                      NaN
# 610            4.0                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# ...

# %% [markdown]
# # Here we are using Corrwith which works as correlation and give us the result

# %%
a="Toy Story (1995)"
correlations = movie_user.corrwith(movie_user[a])
correlations.head(10)
# Out:
# C:\Users\Parth\anaconda3\lib\site-packages\numpy\lib\function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\Parth\anaconda3\lib\site-packages\numpy\lib\function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# title
# '71 (2014)                                      NaN
# 'Hellboy': The Seeds of Creation (2004)         NaN
# 'Round Midnight (1986)                          NaN
# 'Salem's Lot (2004)                             NaN
# 'Til There Was You (1997)                       NaN
# 'Tis the Season for Love (2015)                 NaN
# 'burbs, The (1989)                         0.240563
# 'night Mother (1986)                            NaN
# (500) Days of Summer (2009)                0.353833
# *batteries not included (1987)            -0.427425
# dtype: float64

# %% [markdown]
# # Problem with this is we get alot of null values thus removing the null values

# %%
recommendation = pd.DataFrame(correlations,columns=['Correlation'])
recommendation.dropna(inplace=True)
recommendation = recommendation.join(Average_ratings['Total Ratings'])
recommendation.head()
# Out:
#                                 Correlation  Total Ratings
# title
# 'burbs, The (1989)                 0.240563             17
# (500) Days of Summer (2009)        0.353833             42
# *batteries not included (1987)    -0.427425              7
# 10 Cent Pistol (2015)              1.000000              2
# 10 Cloverfield Lane (2016)        -0.285732             14

# %% [markdown]
# # sorting all the recommendation in descending

# %%
recc = recommendation[recommendation['Total Ratings']>10].sort_values('Correlation',ascending=False).reset_index()

# %%
recc = recc.merge(movies,on='title', how='left')
print('The recommandation  for the movie:',a)
recc.head(10)
# Out:
# The recommandation  for the movie: Toy Story (1995)
#                                     title  Correlation  Total Ratings  \
# 0                        Toy Story (1995)     1.000000            215
# 1                    The Nice Guys (2016)     0.968694             15
# 2  Avengers: Infinity War - Part I (2018)     0.942264             13
# 3              Blues Brothers 2000 (1998)     0.935897             12
# 4                          Singles (1992)     0.922331             11
# 5                   22 Jump Street (2014)     0.913282             19
# 6       Passion of the Christ, The (2004)     0.903757             13
# 7       Untitled Spider-Man Reboot (2017)     0.898497             16
# 8                          Dunkirk (2017)     0.890389             13
# 9                          48 Hrs. (1982)     0.888116             11
#
#    movieId                                       genres
# 0        1  Adventure|Animation|Children|Comedy|Fantasy
# ...
